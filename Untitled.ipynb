# %%
# Code copied from https://medium.com/the-21st-century/google-dopamine-new-rl-framework-f84a35b7fb3f

import numpy as np
import os
#DQN for baselines
from dopamine.agents.dqn import dqn_agent
from dopamine.discrete_domains import run_experiment
from dopamine.colab import utils as colab_utils
from dopamine.discrete_domains import atari_lib
#warnings
from absl import flags

import gin.tf

# %%
#where to store training logs
BASE_PATH = '/tmp/colab_dope_run'  # @param
#which arcade environment?
GAME = 'Pong'  # @param

# %%
#define where to store log data
LOG_PATH = os.path.join(BASE_PATH, 'basic_agent', GAME) 
class BasicAgent(object):
  """This agent randomly selects an action and sticks to it. It will change
  actions with probability switch_prob."""
  def __init__(self, sess, num_actions, switch_prob=0.1):
    #tensorflow session
    self._sess = sess
    #how many possible actions can it take?
    self._num_actions = num_actions
    # probability of switching actions in the next timestep?
    self._switch_prob = switch_prob
    #initialize the action to take (randomly)
    self._last_action = np.random.randint(num_actions)
    #not debugging
    self.eval_mode = False
  

  #policy here
  def _choose_action(self):
    if np.random.random() <= self._switch_prob:
      self._last_action = np.random.randint(self._num_actions)
    return self._last_action
    
  #when it checkpoints during training
  def bundle_and_checkpoint(self, unused_checkpoint_dir, unused_iteration):
    pass
    
  #loading from checkpoint
  def unbundle(self, unused_checkpoint_dir, unused_checkpoint_version,
               unused_data):
    pass
  

  def begin_episode(self, unused_observation):
    return self._choose_action()
  
 
  def end_episode(self, unused_reward):
    pass
  
 
  def step(self, reward, observation):
    return self._choose_action()
  
def create_basic_agent(sess, environment, summary_writer=None):
    return BasicAgent(sess, num_actions=environment.action_space.n,
                     switch_prob=0.2)

# %%
config = """
import dopamine.discrete_domains.atari_lib
import dopamine.discrete_domains.run_experiment
atari_lib.create_atari_environment.game_name = '{}'
atari_lib.create_atari_environment.sticky_actions = True
""".format(GAME)

gin.parse_config(config, skip_unknown=False)

basic_runner = run_experiment.Runner(LOG_PATH,
                                      create_basic_agent,
                                      num_iterations=200,
                                      training_steps=10,
                                      evaluation_steps=10,
                                      max_steps_per_episode=100)

# %%
print('Training basic agent, please be patient, it may take a while...')
basic_runner.run_experiment()
print('Done training!')
# Out:
# Training basic agent, please be patient, it may take a while...
# INFO:tensorflow:Beginning training...
# INFO:tensorflow:Starting iteration 0
# INFO:tensorflow:Average undiscounted return per training episode: -1.00
# INFO:tensorflow:Average training steps per second: 334.72
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 1
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 738.16
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 2
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 717.51
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 3
# INFO:tensorflow:Average undiscounted return per training episode: 1.00
# INFO:tensorflow:Average training steps per second: 734.33
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 4
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 719.50
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 5
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 730.11
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 6
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 719.66
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 7
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 721.15
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 8
# INFO:tensorflow:Average undiscounted return per training episode: 0.00
# INFO:tensorflow:Average training steps per second: 744.72
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 9
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 732.74
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 10
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 737.15
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 11
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 715.53
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 12
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 743.25
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 13
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 730.79
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 14
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 730.60
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 15
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 736.14
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 16
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 744.02
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 17
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 734.15
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 18
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 739.76
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 19
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 735.87
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 20
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 737.59
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 21
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 741.78
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 22
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 749.04
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 23
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 727.97
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 24
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 723.42
# INFO:tensorflow:Average undiscounted return per evaluation episode: 0.00
# INFO:tensorflow:Starting iteration 25
# INFO:tensorflow:Average undiscounted return per training episode: -1.00
# INFO:tensorflow:Average training steps per second: 731.37
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 162
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 752.46
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 163
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 730.64
# INFO:tensorflow:Average undiscounted return per evaluation episode: 1.00
# INFO:tensorflow:Starting iteration 164
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 755.21
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 165
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 727.28
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 166
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 746.53
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 167
# INFO:tensorflow:Average undiscounted return per training episode: -1.00
# INFO:tensorflow:Average training steps per second: 736.38
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 168
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 745.71
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 169
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 736.41
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 170
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 746.16
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 171
# INFO:tensorflow:Average undiscounted return per training episode: -1.00
# INFO:tensorflow:Average training steps per second: 763.12
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 172
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 743.07
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 173
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 743.30
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 174
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 735.95
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 175
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 736.56
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 176
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 735.02
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 177
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 739.22
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 178
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 742.30
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 179
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 725.73
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 180
# INFO:tensorflow:Average undiscounted return per training episode: 1.00
# INFO:tensorflow:Average training steps per second: 734.75
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 181
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 752.49
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 182
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 744.90
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 183
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 732.29
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 184
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 738.04
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 185
# INFO:tensorflow:Average undiscounted return per training episode: -1.00
# INFO:tensorflow:Average training steps per second: 726.39
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 186
# INFO:tensorflow:Average undiscounted return per training episode: 0.00
# INFO:tensorflow:Average training steps per second: 733.22
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 187
# INFO:tensorflow:Average undiscounted return per training episode: 1.00
# INFO:tensorflow:Average training steps per second: 740.86
# INFO:tensorflow:Average undiscounted return per evaluation episode: -1.00
# INFO:tensorflow:Starting iteration 188
# INFO:tensorflow:Average undiscounted return per training episode: 0.00
# INFO:tensorflow:Average training steps per second: 744.87
# INFO:tensorflow:Average undiscounted return per evaluation episode: 0.00
# INFO:tensorflow:Starting iteration 189
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 739.25
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 190
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 739.97
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 191
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 740.77
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 192
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 748.60
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 193
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 740.27
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 194
# INFO:tensorflow:Average undiscounted return per training episode: 0.00
# INFO:tensorflow:Average training steps per second: 726.08
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 195
# INFO:tensorflow:Average undiscounted return per training episode: 0.00
# INFO:tensorflow:Average training steps per second: 728.64
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 196
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 726.82
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 197
# INFO:tensorflow:Average undiscounted return per training episode: 0.00
# INFO:tensorflow:Average training steps per second: 745.88
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 198
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 735.46
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# INFO:tensorflow:Starting iteration 199
# INFO:tensorflow:Average undiscounted return per training episode: -2.00
# INFO:tensorflow:Average training steps per second: 733.35
# INFO:tensorflow:Average undiscounted return per evaluation episode: -2.00
# Done training!

# %%
# !gsutil -q -m cp -R gs://download-dopamine-rl/preprocessed-benchmarks/* /content/
experimental_data = colab_utils.load_baselines('/content')
basic_data = colab_utils.read_experiment(log_path=LOG_PATH, verbose=True)
basic_data['agent'] = 'BasicAgent'
basic_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(basic_data, how='outer')
# Out:
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: Destination URL must name a directory, bucket, or bucket
# subdirectory for the multiple source form of the cp command.
# CommandException: 308 files/objects could not be transferred.
# Reading statistics from: /tmp/colab_dope_run/basic_agent/Pong//logs/log_199
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-7266c0b6c681> in <module>
#       4 basic_data['agent'] = 'BasicAgent'
#       5 basic_data['run_number'] = 1
# ----> 6 experimental_data[GAME] = experimental_data[GAME].merge(basic_data, how='outer')
#
# KeyError: 'Pong'

# %%
import seaborn as sns
import matplotlib.pyplot as pltfig, ax = plt.subplots(figsize=(16,8))
sns.tsplot(data=experimental_data[GAME], time='iteration', unit='run_number', condition='agent', value='train_episode_returns', ax=ax)
plt.title(GAME)
plt.show()
